# %% [markdown]
# # Retail Superstore EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)

# %% [markdown]
# ## Load dataset

# %%
df = pd.read_csv("../data/superstore.csv", parse_dates=["Order Date"], encoding="latin1")
df.head()
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID    Customer Name    Segment  \
# 0       1  CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520      Claire Gute   Consumer
# 1       2  CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520      Claire Gute   Consumer
# 2       3  CA-2016-138688 2016-06-12   6/16/2016    Second Class    DV-13045  Darrin Van Huff  Corporate
# 3       4  US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335   Sean O'Donnell   Consumer
# 4       5  US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335   Sean O'Donnell   Consumer
#
#          Country             City       State  Postal Code Region       Product ID         Category Sub-Category  \
# 0  United States        Henderson    Kentucky        42420  South  FUR-BO-10001798        Furniture    Bookcases
# 1  United States        Henderson    Kentucky        42420  South  FUR-CH-10000454        Furniture       Chairs
# ...

# %% [markdown]
# ## Inspect data structure

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# ## Check missing values

# %%
df.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.describe()
# Out:
#             Row ID                     Order Date   Postal Code         Sales     Quantity     Discount       Profit
# count  9994.000000                           9994   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   4997.500000  2016-04-30 00:07:12.259355648  55190.379428    229.858001     3.789574     0.156203    28.656896
# min       1.000000            2014-01-03 00:00:00   1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    2499.250000            2015-05-23 00:00:00  23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    4997.500000            2016-06-26 00:00:00  56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    7495.750000            2017-05-14 00:00:00  90008.000000    209.940000     5.000000     0.200000    29.364000
# max    9994.000000            2017-12-30 00:00:00  99301.000000  22638.480000    14.000000     0.800000  8399.976000
# ...

# %% [markdown]
# ## Sales over time

# %%
sales_over_time = (
    df.set_index("Order Date")
      .resample("ME")["Sales"] 
      .sum()
)

plt.figure(figsize=(10,5))
plt.plot(sales_over_time.index, sales_over_time.values)
plt.title("Monthly Sales Over Time")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Profit by category

# %%
profit_by_category = (
    df.groupby("Category")["Profit"]
      .sum()
      .sort_values(ascending=False)
)

plt.figure(figsize=(8,5))
plt.bar(profit_by_category.index, profit_by_category.values)
plt.title("Total Profit by Category")
plt.xlabel("Category")
plt.ylabel("Total Profit")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Profit vs discount

# %%
sample = df.sample(n=5000, random_state=42) if len(df) > 5000 else df.copy()

plt.figure(figsize=(8,5))
plt.scatter(sample["Discount"], sample["Profit"], alpha=0.4)
plt.title("Profit vs Discount (sample)")
plt.xlabel("Discount")
plt.ylabel("Profit")
plt.grid(True, linestyle="--", alpha=0.3)
plt.tight_layout()
plt.show()

# %%
df["discount_bin"] = pd.cut(
    df["Discount"],
    bins=[-0.01, 0.10, 0.30, 0.50, 1.00],
    labels=["0-10%", "10-30%", "30-50%", "50%+"]
)

total_profit_by_bin = (
    df.groupby("discount_bin", observed=False)["Profit"]
      .sum()
      .sort_index()
)

# Removed print statements — no console output

plt.figure(figsize=(8, 5))
plt.bar(total_profit_by_bin.index.astype(str), total_profit_by_bin.values)
plt.title("Total Profit by Discount Band")
plt.xlabel("Discount Band")
plt.ylabel("Total Profit")
plt.tight_layout()
plt.show()
